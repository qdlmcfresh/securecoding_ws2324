# %% [markdown]
# # Attack a password check
#
# #### Learning goals:
# - Learn how a "bad" password check looks like
# - Learn how to run code from C files on ChipWhisperer
# - Learn how to read output from ChipWhisperer
# - Learn how to exploit different program flows
# - Learn how a SAD attack works

# %%
# %load_ext autoreload
# %autoreload 2

import os
from cwtoolbox import CaptureDevice
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 1. Record traces from passwordcheck.c

# %%
capture_device = CaptureDevice.create("CWLITEXMEGA")
capture_device.compile(file=os.path.abspath("passwordcheck.c"))
capture_device.flash()
# Out:
# XMEGA Programming flash...
# XMEGA Reading flash...
# Verified flash OK, 2207 bytes

# %%
data = capture_device.capture(
    number_of_traces=1,
    number_of_samples=100,
    input=lambda _: 8 * [0],
)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 27.15it/s]

# %% [markdown]
# <div style="border: 3px solid plum; border-radius: 5px; padding: 5px; width: calc(100% - 20px);">
# <div class="h2" style="font-variant: all-small-caps;">Exercise 1</div>
#
# 1. Understand [passwordcheck.c](passwordcheck.c). What is `setup()`, `run()`, and `teardown()`?
# 2. Think about problems in this C code.
#    What happens if `input` smaller than the stored password?
#
# </div>

# %% [markdown]
# 1.
# 2. out of bounds read

# %% [markdown]
# <div style="border: 3px solid plum; border-radius: 5px; padding: 5px; width: calc(100% - 20px);">
# <div class="h2" style="font-variant: all-small-caps;">Exercise 2</div>
#
# 1. Record traces with different inputs.
# 2. Plot the recorded traces. Is there a difference?
#
# </div>

# %%
password = 'infineon'

def generate_input(n):
    r = []
    for x in range(n):
        r.append(ord(password[x]))
    for x in range(n, len(password)):
        r.append(0)
    return r

print(generate_input(2))
# Out:
# [105, 110, 0, 0, 0, 0, 0, 0]

# %%
data = capture_device.capture(
    number_of_traces=8,
    number_of_samples=700,
    input=generate_input
)
# Out:
# 100%|██████████| 8/8 [00:00<00:00, 141.72it/s]

# %%
import plotly.graph_objects as pgo
fig = pgo.Figure()
fig.add_trace(pgo.Scatter(y=data["trace"][2]))
# Out:
# <div>                            <div id="beecd096-cccc-4dab-b55e-0605483ced2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("beecd096-cccc-4dab-b55e-0605483ced2d")) {                    Plotly.newPlot(                        "beecd096-cccc-4dab-b55e-0605483ced2d",                        [{"y":[0.1005859375,-0.2705078125,-0.125,-0.125,0.01171875,-0.3642578125,-0.2021484375,-0.1962890625,-0.041015625,-0.46875,-0.298828125,-0.2587890625,-0.08203125,-0.275390625,-0.12109375,-0.1220703125,0.021484375,-0.1337890625,-0.0087890625,-0.0419921875,0.083984375,-0.2666015625,-0.1181640625,-0.1162109375,0.029296875,-0.1015625,0.0263671875,-0.0068359375,0.1103515625,-0.240234375,-0.1015625,-0.10546875,0.037109375,-0.15234375,-0.0205078125,-0.037109375,0.08984375,-0.2802734375,-0.125,-0.1220703125,0.021484375,-0.3994140625,-0.2373046875,-0.208984375,-0.0439453125,-0.2568359375,-0.1123046875,-0.1103515625,0.0322265625,-0.3505859375,-0.1806640625,-0.162109375,-0.005859375,-0.1943359375,-0.0498046875,-0.0634765625,0.072265625,-0.0771484375,0
-0.150390625,-0.0146484375,-0.02734375,0.1064453125,-0.12890625,0.0,-0.0244140625,0.10546875,-0.166015625,-0.029296875,-0.0439453125,0.091796875,-0.12890625,0.0068359375,-0.0126953125,0.1123046875,-0.1171875,0.015625,-0.0048828125,0.125,-0.1015625,0.02734375,-0.0009765625,0.1279296875,-0.4736328125,-0.328125,-0.2626953125,-0.0732421875,-0.5,-0.4384765625,-0.3505859375,-0.14453125,-0.5,-0.3779296875,-0.29296875,-0.09375,-0.5,-0.4189453125,-0.322265625,-0.1142578125,-0.193359375,-0.01953125,-0.0126953125,0.1220703125,-0.38671875,-0.216796875,-0.1787109375,-0.005859375,-0.1103515625,0.0390625,0.025390625,0.146484375,-0.4970703125,-0.392578125,-0.3251953125,-0.1259765625,-0.2861328125,-0.10546875,-0.1025390625,0.0498046875,-0.1435546875,-0.0009765625,-0.017578125,0.1142578125,-0.134765625,-0.00390625,-0.0166015625,0.1181640625,-0.0966796875,0.0380859375,0.0166015625,0.1455078125,-0.10546875,0.0224609375,0.0,0.12890625,-0.087890625,0.041015625,0.0185546875,0.1357421875,-0.177734375,-0.0400390625,-0.0517578125,0.087890625,-0.150390625,-0.0009765625,-0.021484375,0.11328125,-0.00390625,0.1162109375,0.0771484375,0.1884765625,-0.0546875,0.06640625,0.03125,0.1513671875,-0.001953125,0.1162109375,0.072265625,0.18359375,-0.076171875,0.046875,0.01171875,0.1337890625,-0.031 ...

# %%
import numpy as np
def crack_password():
    password = []
    while True:
        trace = capture_device.capture(
            number_of_traces=ord("~")-ord(" "),
            number_of_samples=200 + len(password) * 100,
            input=lambda i: password  + [ord(" ") + i],
        )["trace"]
        corr = np.corrcoef(trace)[0]
        idx = corr.argmin()
        if corr[idx] > 0.95:
            return password
        else:
            password = password + [idx + 0x20]
        print(f"Current Guess:{bytes(password)}")

# %%
bytes(crack_password()).decode()
# Out:
# 100%|██████████| 94/94 [00:03<00:00, 29.33it/s]
# Current Guess:b't'
# 100%|██████████| 94/94 [00:03<00:00, 29.61it/s]
# Current Guess:b'te'
# 100%|██████████| 94/94 [00:03<00:00, 29.85it/s]
# Current Guess:b'tes'
# 100%|██████████| 94/94 [00:03<00:00, 30.21it/s]
# Current Guess:b'test'
# 100%|██████████| 94/94 [00:03<00:00, 29.73it/s]
# 'test'

# %% [markdown]
# <div style="border: 3px solid plum; border-radius: 5px; padding: 5px; width: calc(100% - 20px);">
# <div class="h2" style="font-variant: all-small-caps;">Exercise 3</div>
#
# Crack the password using the differences!
#
# 1. Write down the attack in pseudocode.
# 2. Implement an automated attack.
#
# </div>

# %% [markdown]
# <div style="border: 3px solid plum; border-radius: 5px; padding: 5px; width: calc(100% - 20px);">
# <div class="h2" style="font-variant: all-small-caps;">Exercise 4</div>
#
# 1. Change `stored_password` and download the program.
# 2. Exchange your ChipWhisperer with another student.
# 3. Can you crack the password of your colleague?
#
# </div>
